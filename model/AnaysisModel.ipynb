# %% [markdown]
# This is the Analysis Model of the KPI

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_excel('Performance_Management-History_Query-Template_3G_Availability-HAZEL_NCUBE-20240326104334.xlsx')
df_site_name = pd.read_excel('site_names.xlsx')

#(df_site_name.shape)
# Out:
# /home/takudzwa/anaconda3/envs/condavenv/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#        Index           Begin Time             End Time Granularity  \
# 0          1  2024-02-01 00:00:00  2024-02-02 00:00:00       1 day
# 1          2  2024-02-01 00:00:00  2024-02-02 00:00:00       1 day
# 2          3  2024-02-01 00:00:00  2024-02-02 00:00:00       1 day
# 3          4  2024-02-01 00:00:00  2024-02-02 00:00:00       1 day
# 4          5  2024-02-01 00:00:00  2024-02-02 00:00:00       1 day
# ...      ...                  ...                  ...         ...
# 45812  45813  2024-03-25 00:00:00  2024-03-26 00:00:00       1 day
# 45813  45814  2024-03-25 00:00:00  2024-03-26 00:00:00       1 day
# 45814  45815  2024-03-25 00:00:00  2024-03-26 00:00:00       1 day
# 45815  45816  2024-03-25 00:00:00  2024-03-26 00:00:00       1 day
# 45816  45817  2024-03-25 00:00:00  2024-03-26 00:00:00       1 day
#
#        SubnetWork ID          SubnetWork Name  ManagedElement ID  \
# 0                223  MID1001-CN-ZBSC001(223)                223
# 1                223  MID1001-CN-ZBSC001(223)                223
# 2                223  MID1001-CN-ZBSC001(223)                223
# 3                223  MID1001-CN-ZBSC001(223)                223
# 4                223  MID1001-CN-ZBSC001(223)                223
# ...              ...                      ...                ...
# 45812            223  MID1001-CN-ZBSC001(223)                223
# 45813            223  MID1001-CN-ZBSC001(223)                223
# 45814            223  MID1001-CN-ZBSC001(223)                223
# 45815            223  MID1001-CN-ZBSC001(223)                223
# 45816            223  MID1001-CN-ZBSC001(223)                223
#
#                Managed Element  SITE ID       SITE Name  BTS ID  \
# 0      MID1001-CN-ZBSC001(223)     1786  MID0201-RN-IMG       1
# 1      MID1001-CN-ZBSC001(223)     1786  MID0201-RN-IMG       2
# 2      MID1001-CN-ZBSC001(223)     1786  MID0201-RN-IMG       3
# 3      MID1001-CN-ZBSC001(223)     1786  MID0201-RN-IMG       4
# 4      MID1001-CN-ZBSC001(223)     1786  MID0201-RN-IMG       5
# ...                        ...      ...             ...     ...
# 45812  MID1001-CN-ZBSC001(223)     3217  MID0224-RN-IMG       5
# 45813  MID1001-CN-ZBSC001(223)     3217  MID0224-RN-IMG       6
# 45814  MID1001-CN-ZBSC001(223)     4083  MID0240-RN-IMG       1
# 45815  MID1001-CN-ZBSC001(223)     4083  MID0240-RN-IMG       2
# 45816  MID1001-CN-ZBSC001(223)     4083  MID0240-RN-IMG       3
#
#                BTS Name  306004:TCH in service rate(%)  \
# 0      MID0201-RN-IMG1A                         1.0000
# 1      MID0201-RN-IMG1B                         1.0000
# 2      MID0201-RN-IMG1C                         1.0000
# 3      MID0201-RN-IMD1A                         1.0000
# 4      MID0201-RN-IMD1B                         1.0000
# ...                 ...                            ...
# 45812  MID0224-RN-IMD1B                         0.5195
# 45813  MID0224-RN-IMD1C                         0.5195
# 45814  MID0240-RN-OMM1A                         1.0000
# 45815  MID0240-RN-OMM1B                         1.0000
# 45816  MID0240-RN-OMM1C                         1.0000
#
#        306024:TCH total traffic number(erl)  \
# 0                                   13.2256
# 1                                   29.3842
# 2                                   10.4822
# 3                                   10.1656
# 4                                    6.9364
# ...                                     ...
# 45812                                4.8239
# 45813                               19.7644
# 45814                              217.7517
# 45815                              137.0042
# 45816                              260.4664
#
#        900134113:U31_Aggregate PS Data (MB)_900134_1_gv4.bsc-MO
# 0                                                    127
# 1                                                    249
# 2                                                    231
# 3                                                    232
# 4                                                     70
# ...                                                  ...
# 45812                                                 90
# 45813                                                636
# 45814                                               1331
# 45815                                               1530
# 45816                                               2084
#
# [45817 rows x 15 columns]

# %%
df_2 = pd.read_excel('Performance Management-History Query-Temporary Query4-HAZEL NCUBE-2024050210180.xlsx')
# Out:
# /home/takudzwa/anaconda3/envs/condavenv/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298870 entries, 0 to 298869
# Data columns (total 16 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   Begin Time                                     298870 non-null  object
#  1   End Time                                       298870 non-null  object
#  2   Granularity                                    298870 non-null  object
#  3   SubnetWork ID                                  298870 non-null  int64
#  4   SubnetWork Name                                298870 non-null  object
#  5   ManagedElement ID                              298870 non-null  int64
#  6   RNC Managed NE                                 298870 non-null  object
#  7   NodeB ID                                       298870 non-null  int64
#  8   NodeB Name                                     298870 non-null  object
#  9   Cell ID                                        298870 non-null  int64
#  10  Cell Name                                      298870 non-null  object
#  11  Cell Traffic Volume, CS(Erl)                   298870 non-null  float64
#  12  Traffic Volume, CS 64k(Erl)                    298870 non-null  float64
#  13  Traffic Volume, CS AMR 12.2(Erl)               298870 non-null  float64
#  14  U31_3G cell availability_900943_1_UROP.RNC-MO  298870 non-null  float64
#  15  Data Integrity                                 298870 non-null  float64
# dtypes: float64(5), int64(4), object(7)
# memory usage: 36.5+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45817 entries, 0 to 45816
# Data columns (total 15 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Index                                                     45817 non-null  int64
#  1   Begin Time                                                45817 non-null  object
#  2   End Time                                                  45817 non-null  object
#  3   Granularity                                               45817 non-null  object
#  4   SubnetWork ID                                             45817 non-null  int64
#  5   SubnetWork Name                                           45817 non-null  object
#  6   ManagedElement ID                                         45817 non-null  int64
#  7   Managed Element                                           45817 non-null  object
#  8   SITE ID                                                   45817 non-null  int64
#  9   SITE Name                                                 45817 non-null  object
#  10  BTS ID                                                    45817 non-null  int64
#  11  BTS Name                                                  45817 non-null  object
#  12  306004:TCH in service rate(%)                             45817 non-null  float64
#  13  306024:TCH total traffic number(erl)                      45817 non-null  float64
#  14  900134113:U31_Aggregate PS Data (MB)_900134_1_gv4.bsc-MO  45817 non-null  int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 5.2+ MB

# %%
#Changing the names so that the data sets can be merged
df['SiteCode'] = df['SITE Name']
df['ServiceRate'] = df['306004:TCH in service rate(%)']
df['TotalTraffic'] = df['306024:TCH total traffic number(erl)']
df['PSData'] = df['900134113:U31_Aggregate PS Data (MB)_900134_1_gv4.bsc-MO']
 
    
df_site_name['SiteCode']= df_site_name['Unnamed: 0']
df_site_name['SiteName']= df_site_name['Unnamed: 1']
df_site = df_site_name[['SiteCode','SiteName']]
#making the site code values the same for both dataset 
df['SiteCode'] = df['SiteCode'].str.split('-', expand=True)[0]

# %%
df['Begin Time'].min()
# Out:
# '2024-02-01 00:00:00'

# %%
#Data Cleaning
df_Nan = df.isna().sum()
df_is_Null = df.isnull().sum()
df_missing = df.dropna()
#Check Completenes 
nan_counts_per_column = df.isna().sum(axis=0)
total_rows = df.shape[0]
percent_missing_column = (nan_counts_per_column / total_rows) * 100
#print(percent_missing_column)
#Duplicates
duplicates = df_missing.duplicated()
duplicates
df_duplicates = df_missing.drop_duplicates()
#df_duplicates

# %%
#Check Consistency

df_duplicates.dtypes
try:
  df_duplicates['Begin Time'] = pd.to_datetime(df_duplicates['Begin Time'], format='%Y-%m-%d')
  df_duplicates['End Time'] = pd.to_datetime(df_duplicates['End Time'], format='%Y-%m-%d ')
except ValueError:  
  try:
    df_duplicates['Begin Time'] = pd.to_datetime(df_duplicates['Begin Time'])
    df_duplicates['End Time'] = pd.to_datetime(df_duplicates['End Time'])
  except pd.errors.ParserError:  
        print("Warning: Could not automatically convert 'Begin Time' and 'End Time' columns to datetime format")

df_duplicates.dtypes
# Out:
# Index                                                                int64
# Begin Time                                                  datetime64[ns]
# End Time                                                    datetime64[ns]
# Granularity                                                         object
# SubnetWork ID                                                        int64
# SubnetWork Name                                                     object
# ManagedElement ID                                                    int64
# Managed Element                                                     object
# SITE ID                                                              int64
# SITE Name                                                           object
# BTS ID                                                               int64
# BTS Name                                                            object
# 306004:TCH in service rate(%)                                      float64
# 306024:TCH total traffic number(erl)                               float64
# 900134113:U31_Aggregate PS Data (MB)_900134_1_gv4.bsc-MO             int64
# SiteCode                                                            object
# ServiceRate                                                        float64
# TotalTraffic                                                       float64
# PSData                                                               int64
# dtype: object

# %%
# data to use 
df_drop = df_duplicates[['Begin Time','End Time','Granularity','Managed Element','SiteCode','BTS Name','ServiceRate','TotalTraffic']]
df_drop
# Out:
#       Begin Time   End Time Granularity          Managed Element SiteCode  \
# 0     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 1     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 2     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 3     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 4     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# ...          ...        ...         ...                      ...      ...
# 45812 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0224
# 45813 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0224
# 45814 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0240
# 45815 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0240
# 45816 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0240
#
#                BTS Name  ServiceRate  TotalTraffic
# 0      MID0201-RN-IMG1A       1.0000       13.2256
# 1      MID0201-RN-IMG1B       1.0000       29.3842
# 2      MID0201-RN-IMG1C       1.0000       10.4822
# 3      MID0201-RN-IMD1A       1.0000       10.1656
# 4      MID0201-RN-IMD1B       1.0000        6.9364
# ...                 ...          ...           ...
# 45812  MID0224-RN-IMD1B       0.5195        4.8239
# 45813  MID0224-RN-IMD1C       0.5195       19.7644
# 45814  MID0240-RN-OMM1A       1.0000      217.7517
# 45815  MID0240-RN-OMM1B       1.0000      137.0042
# 45816  MID0240-RN-OMM1C       1.0000      260.4664
#
# [45817 rows x 8 columns]

# %%
#checking outliers for Service Rate using domain knowlege 

df_outlier1 = df_drop.ServiceRate < 0 
print('NUmber of Outlier is the lower bound',df_outlier1.sum())
df_outlier2 = df_drop.ServiceRate > 1 
print('Number of Outlier in the Upper Bound',df_outlier2.sum())

#removing

# df_without)outliers1 = df_drop[
# Out:
# NUmber of Outlier is the lower bound 0
# Number of Outlier in the Upper Bound 0

# %%
sns.boxplot(df_drop.ServiceRate)
# Out:
# <Axes: ylabel='ServiceRate'>

# %%
df_drop.TotalTraffic.median()
print('Minimum Value',df_drop.TotalTraffic.min() )
print('Standard DEviation',df_drop.TotalTraffic.std() )
print('Average',df_drop.TotalTraffic.mean() )
print('Median',df_drop.TotalTraffic.median() )
print('Maximim Value',df_drop.TotalTraffic.max() )
min_threshold , max_threshold = df_drop.TotalTraffic.quantile([0.00,1])
df_outlier1 = df_drop.TotalTraffic < min_threshold
print('NUmber of Outlier is the lower bound for TotalTraffic',df_outlier1.sum())
df_outlier2 = df_drop.TotalTraffic > max_threshold
print('Number of Outlier in the Upper Bound for Total Traffic',df_outlier2.sum())
# Out:
# Minimum Value 0.0
# Standard DEviation 119.72476621287773
# Average 121.50566784599603
# Median 81.2789
# Maximim Value 1007.5819
# NUmber of Outlier is the lower bound for TotalTraffic 0
# Number of Outlier in the Upper Bound for Total Traffic 0

# %%
sns.boxplot(df_drop.TotalTraffic)
# Out:
# <Axes: ylabel='TotalTraffic'>

# %%
 df_drop_outlier = df_drop[(df_drop.TotalTraffic < max_threshold) & (df_drop.TotalTraffic >= min_threshold) ]
print(df_drop_outlier.shape)
print('Minimum Value',df_drop_outlier.TotalTraffic.min() )
print('Standard DEviation',df_drop_outlier.TotalTraffic.std() )
print('Average',df_drop_outlier.TotalTraffic.mean() )
print('Median',df_drop_outlier.TotalTraffic.median() )
print('Maximim Value',df_drop_outlier.TotalTraffic.max() )
df_outlier1 = df_drop_outlier.TotalTraffic < min_threshold
print('NUmber of Outlier is the lower bound for TotalTraffic',df_outlier1.sum())
df_outlier2 = df_drop_outlier.TotalTraffic > max_threshold
print('Number of Outlier in the Upper Bound for Total Traffic',df_outlier2.sum())
# Out:
# (45816, 8)
# Minimum Value 0.0
# Standard DEviation 119.65448236665705
# Average 121.48632795966473
# Median 81.27584999999999
# Maximim Value 978.5725
# NUmber of Outlier is the lower bound for TotalTraffic 0
# Number of Outlier in the Upper Bound for Total Traffic 0

# %%
sns.boxplot(df_drop_outlier.TotalTraffic)
df_drop_outlier.TotalTraffic.shape
# Out:
# (45816,)

# %%
#Anomalies in our dataset
# Service is 0 but there is Traffic
df_final = df_drop_outlier[(df_drop_outlier.TotalTraffic > 0) & (df_drop_outlier.ServiceRate == 0) ]
df_processed =  df_drop_outlier[((df_drop_outlier.TotalTraffic == 0) & (df_drop_outlier.ServiceRate == 0)) | (df_drop_outlier.TotalTraffic >= 0) & (df_drop_outlier.ServiceRate > 0) ]
#df_final
df_processed
# Out:
#       Begin Time   End Time Granularity          Managed Element SiteCode  \
# 0     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 1     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 2     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 3     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# 4     2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201
# ...          ...        ...         ...                      ...      ...
# 45812 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0224
# 45813 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0224
# 45814 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0240
# 45815 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0240
# 45816 2024-03-25 2024-03-26       1 day  MID1001-CN-ZBSC001(223)  MID0240
#
#                BTS Name  ServiceRate  TotalTraffic
# 0      MID0201-RN-IMG1A       1.0000       13.2256
# 1      MID0201-RN-IMG1B       1.0000       29.3842
# 2      MID0201-RN-IMG1C       1.0000       10.4822
# 3      MID0201-RN-IMD1A       1.0000       10.1656
# 4      MID0201-RN-IMD1B       1.0000        6.9364
# ...                 ...          ...           ...
# 45812  MID0224-RN-IMD1B       0.5195        4.8239
# 45813  MID0224-RN-IMD1C       0.5195       19.7644
# 45814  MID0240-RN-OMM1A       1.0000      217.7517
# 45815  MID0240-RN-OMM1B       1.0000      137.0042
# 45816  MID0240-RN-OMM1C       1.0000      260.4664
#
# [45816 rows x 8 columns]

# %%
df_site = df_site_name[['SiteCode','SiteName']]
#Duplicates
print('Before duplicates removal',df_site.shape)
df_duplicates = df_site.drop_duplicates()
print('After Duplicates Removal',df_duplicates.shape)
#Mising values
print('Before missing values removal',df_duplicates.shape)
df_missing = df_duplicates.dropna()
print('After missing Removal',df_missing.shape)

df_site_final = df_missing 

print(df_site_final.shape)
# Out:
# Before duplicates removal (703, 2)
# After Duplicates Removal (163, 2)
# Before missing values removal (163, 2)
# After missing Removal (163, 2)
# (163, 2)

# %%
df_merged = df_processed.merge(df_site_final, on='SiteCode', how='left')
if 'Site Code' in df_merged.columns:
    df_merged['SiteCode'] = df_merged['SiteCode'].fillna(df_merged['SiteCode'],inplace =True)  

# df_site = df_site_name[['SiteCode','SiteName']]
#Duplicates
print('DF Porocessed',df_processed.shape)
print('Before duplicates removal',df_merged.shape)
df_duplicate = df_merged.drop_duplicates()
print('After Duplicates Removal',df_duplicate.shape)
#Mising values
print('Before missing values removal',df_duplicate.shape)
df_miss = df_duplicate.dropna()
print('After missing Removal',df_miss.shape)
df_analysis = df_miss

df_analysis.to_excel('/home/takudzwa/Documents/Projects/ProjectGuides/DataScience/Hazel/kpi_analysis/CleanedData/JupyterCleanedDataset.xlsx',index=False)
# Out:
# DF Porocessed (45816, 8)
# Before duplicates removal (45816, 9)
# After Duplicates Removal (45816, 9)
# Before missing values removal (45816, 9)
# After missing Removal (41106, 9)

# %%
df_analysis.SiteCode.unique()
# Out:
# array(['MID0201', 'MID0001', 'MID0003', 'MID0004', 'MID0005', 'MID0006',
#        'MID0007', 'MID0008', 'MID0009', 'MID0010', 'MID0011', 'MID0012',
#        'MID0013', 'MID0014', 'MID0015', 'MID0016', 'MID0017', 'MID0018',
#        'MID0019', 'MID0020', 'MID0021', 'MID0022', 'MID0023', 'MID0024',
#        'MID0025', 'MID0026', 'MID0027', 'MID0028', 'MID0029', 'MID0030',
#        'MID0031', 'MID0032', 'MID0033', 'MID0034', 'MID0035', 'MID0037',
#        'MID0038', 'MID0039', 'MID0040', 'MID0041', 'MID0042', 'MID0043',
#        'MID0045', 'MID0046', 'MID0047', 'MID0048', 'MID0049', 'MID0050',
#        'MID0051', 'MID0052', 'MID0053', 'MID0054', 'MID0060', 'MID0061',
#        'MID0062', 'MID0063', 'MID0064', 'MID0065', 'MID0066', 'MID0067',
#        'MID0069', 'MID0070', 'MID0073', 'MID0100', 'MID0101', 'MID0102',
#        'MID0103', 'MID0104', 'MID0105', 'MID0106', 'MID0107', 'MID0108',
#        'MID0109', 'MID0110', 'MID0111', 'MID0113', 'MID0114', 'MID0116',
#        'MID0117', 'MID0118', 'MID0119', 'MID0120', 'MID0121', 'MID0123',
#        'MID0124', 'MID0125', 'MID0126', 'MID0127', 'MID0128', 'MID0129',
#        'MID0130', 'MID0131', 'MID0132', 'MID0133', 'MID0134', 'MID0136',
#        'MID0137', 'MID0139', 'MID0140', 'MID0141', 'MID0142', 'MID0149',
#        'MID0150', 'MID0155', 'MID0156', 'MID0160', 'MID0162', 'MID0163',
#        'MID0165', 'MID0166', 'MID0167', 'MID0168', 'MID0169', 'MID0170',
#        'MID0171', 'MID0172', 'MID0173', 'MID0175', 'MID0179', 'MID0180',
#        'MID0182', 'MID0183', 'MID0191', 'MID0192', 'MID0195', 'MID0196',
#        'MID0198', 'MID0199', 'MID1001', 'MID1020', 'MID1051', 'MID0193',
#        'MID0200', 'MID0184', 'MID0099', 'MID0044', 'MID1011', 'MID0207',
#        'MID0213', 'MID0217', 'MID0214', 'MID0206', 'MID0215', 'MID0202',
#        'MID0036', 'MID0056', 'MID0055', 'MID0190', 'MID0218', 'MID0219',
#        'MID0220', 'MID0221', 'MID0084'], dtype=object)

# %%
section_a_mask = df_analysis['SiteCode'].between('MID0001', 'MID0100')
section_b_mask = df_analysis['SiteCode'].between('MID0101', 'MID0219')

section_a = df_analysis[section_a_mask]
section_b = df_analysis[section_b_mask]

print("Section A:")
print(section_a.shape)
print("\nSection B:")
print(section_b.shape)
# Out:
# Section A:
# (19427, 9)
#
# Section B:
# (20062, 9)

# %%
section_b.SiteName.value_counts()
# Out:
# SiteName
# Midlands State University 2    324
# Gokwe 3                        324
# Nyama                          324
# Shurugwi Town                  324
# Zvishavane Town                324
#                               ...
# Chiodza USF                    162
# Gangata                        162
# Mabasa                         162
# Gweru Innscor Micro            108
# Kwekwe Bus Terminus Micro      108
# Name: count, Length: 78, dtype: int64

# %%
df_analysis.sample(20)
print(df_analysis.shape)
# Out:
# (41106, 9)

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41106 entries, 0 to 45779
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Begin Time       41106 non-null  datetime64[ns]
#  1   End Time         41106 non-null  datetime64[ns]
#  2   Granularity      41106 non-null  object
#  3   Managed Element  41106 non-null  object
#  4   SiteCode         41106 non-null  object
#  5   BTS Name         41106 non-null  object
#  6   ServiceRate      41106 non-null  float64
#  7   TotalTraffic     41106 non-null  float64
#  8   SiteName         41106 non-null  object
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 3.1+ MB

# %%
df_analysis["Begin Time"].describe()
# Out:
# count                            41106
# mean     2024-02-27 12:35:18.698000128
# min                2024-02-01 00:00:00
# 25%                2024-02-14 00:00:00
# 50%                2024-02-28 00:00:00
# 75%                2024-03-12 00:00:00
# max                2024-03-25 00:00:00
# Name: Begin Time, dtype: object

# %%
df_analysis["End Time"].describe()
# Out:
# count                            41106
# mean     2024-02-28 12:35:18.698000128
# min                2024-02-02 00:00:00
# 25%                2024-02-15 00:00:00
# 50%                2024-02-29 00:00:00
# 75%                2024-03-13 00:00:00
# max                2024-03-26 00:00:00
# Name: End Time, dtype: object

# %%
df_analysis.ServiceRate.describe()
# Out:
# count    41106.000000
# mean         0.960579
# std          0.138963
# min          0.000000
# 25%          0.997300
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: ServiceRate, dtype: float64

# %%
df_analysis.TotalTraffic.describe()
# Out:
# count    41106.000000
# mean       122.904170
# std        121.586505
# min          0.000000
# 25%         34.975950
# 50%         81.598050
# 75%        167.908350
# max        978.572500
# Name: TotalTraffic, dtype: float64

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_analysis['Begin Time'], df_analysis['TotalTraffic'], label='TotalTraffic')
plt.xlabel('Time')
plt.ylabel('Total Traffic')
plt.title('Total Traffic Over Time')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_analysis['Begin Time'], df_analysis['ServiceRate'], label='Service Rate')
plt.xlabel('Time')
plt.ylabel('Service Rate')
plt.title('Service Rate Over Time')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
site_with_low = df_analysis[(df_analysis.ServiceRate == 0) & (df_analysis["End Time"] < "2024-02-28")]
print("Summary Statistics for Sites with 0 Service Rate in The month of February")
site_with_low.SiteName.value_counts()
# Out:
# Summary Statistics for Sites with 0 Service Rate in The month of February
# SiteName
# Sable Chemicals                15
# Zvishavane Birthday            12
# Mkoba 3                        12
# Pakame                          9
# Gweru Second Street Clinic      6
# Midlands State University 2     6
# Redcliff 2                      6
# Golden Quarry                   3
# Nemangwe                        2
# Buchwa                          1
# Name: count, dtype: int64

# %%
site_names = site_with_low['SiteName'].value_counts().index.to_numpy()
site_counts = site_with_low['SiteName'].value_counts().to_numpy()
plt.figure(figsize=(6, 6))  
plt.pie(site_counts, labels=site_names, autopct="%1.1f%%")  
plt.title("Sites with 0 Service Rate in February (Distribution)")
plt.show()

# %%
march_data = df_analysis[(df_analysis.ServiceRate == 0) & (df_analysis["Begin Time"] <= "2024-03-01") & (df_analysis["End Time"] < "2024-03-27")]
site_names = march_data ['SiteName'].value_counts().index.to_numpy()
site_counts = march_data ['SiteName'].value_counts().to_numpy()
plt.figure(figsize=(6, 6))  
plt.pie(site_counts, labels=site_names, autopct="%1.1f%%")  
plt.title("Sites with 0 Service Rate in March (Distribution)")
plt.show()

# %%
#finding relationships between variables
correlations = df_analysis[['ServiceRate', 'TotalTraffic']].corr()
print(correlations)
# Out:
#               ServiceRate  TotalTraffic
# ServiceRate      1.000000      0.118654
# TotalTraffic     0.118654      1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_grouped = df_analysis.groupby(df_analysis['End Time'])['ServiceRate'].mean()
time_interval = df_grouped.index.to_numpy()  
average_service_rate = df_grouped.to_numpy()  


plt.figure(figsize=(10, 5))  # 
plt.plot(time_interval, average_service_rate)
plt.xlabel('Time Interval')
plt.ylabel('Average Service Rate')
plt.title('Average Service Rate by Time Interval')
plt.grid(True)
plt.show()

# %%
df_analysis.SiteName
# Out:
# 0        Midlands State University 2
# 1        Midlands State University 2
# 2        Midlands State University 2
# 3        Midlands State University 2
# 4        Midlands State University 2
#                     ...
# 45763                Zvishavane Peak
# 45764                Zvishavane Peak
# 45777                   Mount Shamba
# 45778                   Mount Shamba
# 45779                   Mount Shamba
# Name: SiteName, Length: 41106, dtype: object

# %%
start_time = '2024-02-01'
end_time = '2024-02-20'

df_name = df_analysis[df_analysis['SiteName'] == 'Milsonia']
mask = (df_name['Begin Time'] >= start_time) & (df_name['End Time'] <= end_time)
filtered_df = df_name.loc[mask]

filtered_df.set_index('Begin Time', inplace=True)

# Plot ServiceRate
plt.figure(figsize=(12, 5))
plt.plot(filtered_df.index, filtered_df['ServiceRate'])
plt.xlabel('Time')
plt.ylabel('Service Rate')
plt.title('Service Rate Over Selected Time Range')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# Plot TotalTraffic
plt.figure(figsize=(12, 6))
plt.scatter(filtered_df.index, filtered_df['ServiceRate'])
plt.xlabel('Time')
plt.ylabel('Total Traffic')
plt.title('Total Traffic Over Selected Time Range')
plt.xticks(rotation=0)

plt.grid(True)
plt.show()

# %%
df_name = df_analysis[df_analysis['SiteName'] == 'Milsonia']
df_name.shape
# Out:
# (162, 9)

# %%
df_a = df_analysis[(df_analysis['TotalTraffic'] > 10) & (df_analysis['ServiceRate'] <= 5)]

filtered_df = df_a[(df_a['Begin Time'] >= start_time) & (df_a['Begin Time'] <= end_time]

# Get pie chart slice labels
pie_chart_slice_labels = filtered_df['SiteCode'].to_numpy()


# Get pie chart slice values
pie_chart_slice_values = filtered_df['TotalTraffic'].to_numpy()

# Create a pie chart of the number of sites with traffic less than 10 and service rate less than or equal to 5
plt.pie(pie_chart_slice_values, labels=pie_chart_slice_labels, autopct="%1.1f%%")
plt.title("Pie Chart of Sites with Traffic Less Than 10 and Service Rate Less Than or Equal to 5")
plt.show()
# Out:
#   Cell In[39], line 3
#     filtered_df = df_a[(df_a['Begin Time'] >= start_time) & (df_a['Begin Time'] <= end_time]
#                                                                                            ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.plot(df_analysis['ServiceRate'], df_analysis['TotalTraffic'])
plt.xlabel('ServiceRate')
plt.ylabel('TotalTraffic')
plt.title('ServiceRate vs TotalTraffic (Line Graph)')
plt.grid(True)

plt.show()

# %%
df = pd.read_excel('/home/takudzwa/Documents/Projects/ProjectGuides/DataScience/Hazel/kpi_analysis/CleanedData/CleanedDataset.xlsx')

# %%
df.head(n=1)
# Out:
#   Begin Time   End Time Granularity          Managed Element        SiteCode  \
# 0 2024-02-01 2024-02-02       1 day  MID1001-CN-ZBSC001(223)  MID0201-RN-IMG
#
#            BTS Name  ServiceRate  TotalTraffic  Unnamed: 0  SiteName
# 0  MID0201-RN-IMG1A          1.0       13.2256         NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45817 entries, 0 to 45816
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Begin Time       45817 non-null  datetime64[ns]
#  1   End Time         45817 non-null  datetime64[ns]
#  2   Granularity      45817 non-null  object
#  3   Managed Element  45817 non-null  object
#  4   SiteCode         45817 non-null  object
#  5   BTS Name         45817 non-null  object
#  6   ServiceRate      45817 non-null  float64
#  7   TotalTraffic     45817 non-null  float64
#  8   Unnamed: 0       0 non-null      float64
#  9   SiteName         0 non-null      float64
# dtypes: datetime64[ns](2), float64(4), object(4)
# memory usage: 3.5+ MB

# %%
df['SiteName']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/condavenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SiteName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df['SiteName']
#
# File ~/anaconda3/envs/condavenv/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/envs/condavenv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'SiteName'
